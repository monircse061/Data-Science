# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout,BatchNormalization
from tensorflow.keras.layers import Conv1D,MaxPool1D
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
data= pd.read_csv("G:/Datasets/Dataset_for_Classification.csv")
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 0  ...                  3                        1                 0
# 1  ...                  4                        4                 1
# 2  ...                  3                        2                 0
# 3  ...                  3                        3                 0
# 4  ...                  3                        4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 33 columns]

# %%
label_encoder =  preprocessing.LabelEncoder()
data['BusinessTravel'] = label_encoder.fit_transform(data['BusinessTravel'])
data['Attrition'] = label_encoder.fit_transform(data['Attrition'])
data['Department'] = label_encoder.fit_transform(data['Department'])
data['EducationField'] = label_encoder.fit_transform(data['EducationField'])
data['Gender'] = label_encoder.fit_transform(data['Gender'])
data['JobRole'] = label_encoder.fit_transform(data['JobRole'])
data['MaritalStatus'] = label_encoder.fit_transform(data['MaritalStatus'])
data['OverTime'] = label_encoder.fit_transform(data['OverTime'])

# %%
data.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1               2       1102           2                 1
# 1   49          0               1        279           1                 8
# 2   37          1               2       1373           1                 2
# 3   33          0               1       1392           1                 3
# 4   27          0               2        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               4              1               4  ...
# 3          4               1              1               5  ...
# 4          1               3              1               7  ...
#
#    PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                  3                         1                 0
# 1                  4                         4                 1
# 2                  3                         2                 0
# 3                  3                         3                 0
# 4                  3                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 33 columns]

# %%
target = data['Attrition']
print(pd.value_counts(target))
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
non_Attrition=data[data['Attrition']==0]
Attrition=data[data['Attrition']==1]

# %%
non_Attrition.shape
# Out:
# (1233, 33)

# %%
Attrition.shape
# Out:
# (237, 33)

# %%
non_Attrition=non_Attrition.sample(Attrition.shape[0])
non_Attrition.shape
# Out:
# (237, 33)

# %%
data=Attrition.append(non_Attrition,ignore_index=True)
data
# Out:
#      Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     41          1               2       1102           2                 1
# 1     37          1               2       1373           1                 2
# 2     28          1               2        103           1                24
# 3     36          1               2       1218           2                 9
# 4     34          1               2        699           1                 6
# 5     32          1               1       1125           1                16
# 6     39          1               2        895           2                 5
# 7     24          1               2        813           1                 1
# 8     50          1               2        869           2                 3
# 9     26          1               2       1357           1                25
# 10    41          1               2       1360           1                12
# 11    48          1               2        626           1                 1
# 12    28          1               2       1434           1                 5
# 13    36          1               2        318           1                 9
# 14    46          1               2        669           2                 9
# 15    37          1               2        807           0                 6
# 16    20          1               1        871           1                 6
# 17    25          1               2        240           2                 5
# 18    34          1               1        658           1                 7
# 19    56          1               2        441           1                14
# 20    31          1               2        249           2                 6
# 21    58          1               2        147           1                23
# 22    19          1               2        528           2                22
# 23    31          1               2        542           2                20
# 24    51          1               1       1150           1                 8
# 25    32          1               2       1033           1                 9
# 26    19          1               1        602           2                 1
# 27    19          1               2        303           1                 2
# 28    41          1               2       1356           2                20
# 29    35          1               2        556           1                23
# ..   ...        ...             ...        ...         ...               ...
# 444   41          0               2       1411           1                19
# 445   32          0               2        498           1                 3
# 446   37          0               2        228           2                 6
# 447   38          0               1        216           1                23
# 448   32          0               2       1093           2                 6
# 449   45          0               1        364           1                25
# 450   26          0               2        157           1                 1
# 451   34          0               2        704           2                28
# 452   53          0               2       1436           2                 6
# 453   30          0               2        413           2                 7
# 454   37          0               2        671           1                19
# 455   37          0               2        482           1                 3
# 456   38          0               2        437           2                16
# 457   35          0               2       1395           1                 9
# 458   38          0               1       1394           1                 8
# 459   38          0               2        130           2                 2
# 460   31          0               2        182           1                 8
# 461   34          0               2        735           2                 3
# 462   22          0               2       1230           1                 1
# 463   48          0               2       1221           2                 7
# 464   35          0               2        755           1                 9
# 465   24          0               1        567           1                 2
# 466   58          0               0        350           2                 2
# 467   34          0               2        401           1                 1
# 468   36          0               0        301           2                15
# 469   27          0               1        793           2                 2
# 470   28          0               2        440           1                21
# 471   23          0               2        160           1                 4
# 472   24          0               2       1371           2                10
# 473   56          0               2        713           1                 8
#
#      Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0            2               1              1               1  ...
# 1            2               4              1               4  ...
# 2            3               1              1              19  ...
# 3            4               1              1              27  ...
# 4            1               3              1              31  ...
# 5            1               1              1              33  ...
# 6            3               5              1              42  ...
# 7            3               3              1              45  ...
# 8            2               2              1              47  ...
# 9            3               1              1              55  ...
# 10           3               5              1              58  ...
# 11           2               1              1              64  ...
# 12           4               5              1              65  ...
# 13           3               3              1              90  ...
# 14           2               3              1             118  ...
# 15           4               0              1             133  ...
# 16           3               1              1             137  ...
# 17           3               2              1             142  ...
# 18           3               1              1             147  ...
# 19           4               1              1             161  ...
# 20           4               1              1             163  ...
# 21           4               3              1             165  ...
# 22           1               2              1             167  ...
# 23           3               1              1             175  ...
# 24           4               1              1             179  ...
# 25           3               3              1             190  ...
# 26           1               5              1             235  ...
# 27           3               1              1             243  ...
# 28           2               2              1             248  ...
# 29           2               1              1             261  ...
# ..         ...             ...            ...             ...  ...
# 444          2               1              1             334  ...
# 445          4               3              1             966  ...
# 446          4               3              1             378  ...
# 447          3               1              1              12  ...
# 448          4               3              1             125  ...
# 449          3               3              1            1306  ...
# 450          3               3              1            1952  ...
# 451          3               2              1            2035  ...
# 452          2               2              1             205  ...
# 453          1               2              1             585  ...
# 454          3               1              1            1631  ...
# 455          3               4              1             689  ...
# 456          3               1              1            1583  ...
# 457          4               3              1            2008  ...
# 458          3               3              1            1937  ...
# 459          2               2              1            1125  ...
# 460          5               1              1            1430  ...
# 461          1               3              1            1915  ...
# 462          2               1              1             872  ...
# 463          3               2              1            1466  ...
# 464          4               1              1             496  ...
# 465          1               5              1            1646  ...
# 466          3               3              1            1824  ...
# 467          3               1              1            1447  ...
# 468          4               2              1            2036  ...
# 469          1               1              1            1371  ...
# 470          3               3              1             221  ...
# 471          1               3              1            1735  ...
# 472          4               2              1             507  ...
# 473          3               1              1             241  ...
#
#      PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0                    3                         1                 0
# 1                    3                         2                 0
# 2                    3                         2                 0
# 3                    4                         2                 0
# 4                    3                         3                 0
# 5                    4                         2                 0
# 6                    3                         3                 1
# 7                    3                         1                 1
# 8                    3                         3                 0
# 9                    3                         3                 0
# 10                   3                         4                 0
# 11                   3                         4                 0
# 12                   3                         3                 0
# 13                   3                         1                 1
# 14                   3                         4                 0
# 15                   4                         4                 0
# 16                   3                         2                 0
# 17                   3                         4                 0
# 18                   4                         4                 0
# 19                   3                         1                 3
# 20                   3                         2                 0
# 21                   3                         4                 1
# 22                   3                         4                 0
# 23                   3                         3                 1
# 24                   3                         4                 0
# 25                   4                         1                 0
# 26                   4                         1                 0
# 27                   4                         3                 0
# 28                   4                         4                 0
# 29                   3                         1                 0
# ..                 ...                       ...               ...
# 444                  3                         1                 2
# 445                  3                         3                 1
# 446                  3                         2                 1
# 447                  4                         2                 0
# 448                  3                         1                 0
# 449                  4                         3                 0
# 450                  3                         4                 0
# 451                  4                         4                 2
# 452                  4                         4                 1
# 453                  3                         1                 0
# 454                  3                         1                 3
# 455                  3                         3                 1
# 456                  3                         2                 0
# 457                  3                         2                 0
# 458                  3                         3                 1
# 459                  3                         3                 0
# 460                  3                         3                 0
# 461                  3                         3                 0
# 462                  4                         1                 2
# 463                  3                         1                 3
# 464                  3                         3                 0
# 465                  3                         3                 0
# 466                  4                         4                 1
# 467                  3                         1                 1
# 468                  4                         1                 1
# 469                  4                         2                 0
# 470                  3                         3                 1
# 471                  3                         3                 0
# 472                  3                         4                 1
# 473                  3                         3                 1
#
#      TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                    8                      0                1
# 1                    7                      3                3
# 2                    6                      4                3
# 3                   10                      4                3
# 4                    8                      2                3
# 5                   10                      5                3
# 6                   19                      6                4
# 7                    6                      2                2
# 8                    3                      2                3
# 9                    1                      2                2
# 10                  23                      0                3
# 11                  23                      2                3
# 12                   2                      3                2
# 13                   2                      0                2
# 14                   9                      3                3
# 15                   7                      3                3
# 16                   1                      5                3
# 17                   6                      1                3
# 18                   9                      3                3
# 19                   7                      2                3
# 20                  12                      3                2
# 21                  40                      3                2
# 22                   0                      2                2
# 23                   4                      2                3
# 24                  18                      2                3
# 25                  10                      2                4
# 26                   1                      5                4
# 27                   1                      3                2
# 28                   4                      5                2
# 29                   8                      1                3
# ..                 ...                    ...              ...
# 444                 17                      2                2
# 445                  8                      2                4
# 446                  7                      5                4
# 447                 10                      2                3
# 448                 12                      0                3
# 449                 22                      4                3
# 450                  8                      6                2
# 451                  8                      2                3
# 452                 13                      3                1
# 453                  4                      3                3
# 454                  9                      2                2
# 455                 10                      2                3
# 456                  8                      5                4
# 457                 10                      5                3
# 458                 20                      3                3
# 459                 10                      2                3
# 460                  9                      3                4
# 461                  9                      3                2
# 462                  4                      2                1
# 463                 15                      3                3
# 464                 10                      5                3
# 465                  6                      2                3
# 466                 37                      0                2
# 467                  7                      2                2
# 468                 15                      4                2
# 469                  8                      3                3
# 470                  5                      2                1
# 471                  3                      3                1
# 472                  5                      2                4
# 473                 19                      3                3
#
#      YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                 6                   4                        0
# 1                 0                   0                        0
# 2                 4                   2                        0
# 3                 5                   3                        0
# 4                 4                   2                        1
# 5                10                   2                        6
# 6                 1                   0                        0
# 7                 2                   0                        2
# 8                 3                   2                        0
# 9                 1                   0                        0
# 10               22                  15                       15
# 11                1                   0                        0
# 12                2                   2                        2
# 13                1                   0                        0
# 14                9                   8                        4
# 15                3                   2                        0
# 16                1                   0                        1
# 17                6                   4                        0
# 18                9                   7                        0
# 19                5                   4                        4
# 20                7                   7                        7
# 21               40                  10                       15
# 22                0                   0                        0
# 23                2                   2                        2
# 24                4                   2                        0
# 25                5                   4                        0
# 26                0                   0                        0
# 27                1                   0                        1
# 28                4                   3                        0
# 29                1                   0                        0
# ..              ...                 ...                      ...
# 444               1                   0                        0
# 445               8                   7                        6
# 446               5                   4                        0
# 447               9                   7                        1
# 448              11                   8                        5
# 449               0                   0                        0
# 450               7                   7                        7
# 451               8                   7                        1
# 452               7                   7                        4
# 453               3                   2                        1
# 454               4                   3                        0
# 455              10                   7                        7
# 456               3                   2                        1
# 457              10                   7                        0
# 458              20                  11                        0
# 459               1                   0                        0
# 460               3                   2                        1
# 461               4                   2                        0
# 462               2                   2                        2
# 463               2                   2                        2
# 464               1                   1                        0
# 465               6                   3                        1
# 466              16                   9                       14
# 467               5                   4                        0
# 468              15                  12                       11
# 469               6                   2                        0
# 470               5                   2                        0
# 471               3                   2                        1
# 472               5                   2                        0
# 473               2                   2                        2
#
#      YearsWithCurrManager
# 0                       5
# 1                       0
# 2                       3
# 3                       3
# 4                       3
# 5                       7
# 6                       0
# 7                       0
# 8                       2
# 9                       1
# 10                      8
# 11                      0
# 12                      2
# 13                      0
# 14                      7
# 15                      2
# 16                      0
# 17                      3
# 18                      6
# 19                      3
# 20                      7
# 21                      6
# 22                      0
# 23                      2
# 24                      3
# 25                      4
# 26                      0
# 27                      0
# 28                      2
# 29                      1
# ..                    ...
# 444                     0
# 445                     3
# 446                     1
# 447                     8
# 448                     7
# 449                     0
# 450                     6
# 451                     7
# 452                     5
# 453                     2
# 454                     2
# 455                     8
# 456                     2
# 457                     8
# 458                     7
# 459                     0
# 460                     0
# 461                     1
# 462                     2
# 463                     2
# 464                     0
# 465                     3
# 466                    14
# 467                     2
# 468                    11
# 469                     0
# 470                     2
# 471                     2
# 472                     3
# 473                     2
#
# [474 rows x 33 columns]

# %%
target = data['Attrition']
print(pd.value_counts(target))
# Out:
# 1    237
# 0    237
# Name: Attrition, dtype: int64

# %%
x=data.drop('Attrition',axis=1)
y=data['Attrition']

# %%
x.shape
# Out:
# (474, 32)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
x_train.shape
# Out:
# (379, 32)

# %%
x_test.shape
# Out:
# (95, 32)

# %%
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)
# Out:
# C:\Users\pallab\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\pallab\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\pallab\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by StandardScaler.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
y_train=y_train.to_numpy()
y_test=y_test.to_numpy()

# %%
x_train = x_train.reshape(379,32,1)
x_test = x_test.reshape(95,32,1)

# %%
epochs = 20
model = Sequential()
model.add(Conv1D(32,2,activation='relu',input_shape=(32,1)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(64,2,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_16 (Conv1D)           (None, 31, 32)            96
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 31, 32)            128
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 31, 32)            0
# _________________________________________________________________
# conv1d_17 (Conv1D)           (None, 30, 64)            4160
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 30, 64)            256
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 30, 64)            0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1920)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                122944
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 127,649
# Trainable params: 127,457
# Non-trainable params: 192
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(lr=0.0005),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(x_train ,y_train, epochs=epochs,validation_data=(x_test,y_test),verbose=1)
# Out:
# Train on 379 samples, validate on 95 samples
# Epoch 1/20
# 379/379 [==============================] - 5s 13ms/sample - loss: 0.7580 - accuracy: 0.5858 - val_loss: 0.6661 - val_accuracy: 0.7474
# Epoch 2/20
# 379/379 [==============================] - 0s 1ms/sample - loss: 0.5631 - accuracy: 0.7546 - val_loss: 0.6438 - val_accuracy: 0.7579
# Epoch 3/20
# 379/379 [==============================] - 0s 914us/sample - loss: 0.4653 - accuracy: 0.8021 - val_loss: 0.6350 - val_accuracy: 0.7368
# Epoch 4/20
# 379/379 [==============================] - 0s 1ms/sample - loss: 0.4736 - accuracy: 0.7757 - val_loss: 0.6294 - val_accuracy: 0.6737
# Epoch 5/20
# 379/379 [==============================] - 0s 1ms/sample - loss: 0.4382 - accuracy: 0.8047 - val_loss: 0.6221 - val_accuracy: 0.6421
# Epoch 6/20
# 379/379 [==============================] - 0s 922us/sample - loss: 0.3369 - accuracy: 0.8602 - val_loss: 0.6255 - val_accuracy: 0.6000
# Epoch 7/20
# 379/379 [==============================] - 0s 931us/sample - loss: 0.3274 - accuracy: 0.8786 - val_loss: 0.6318 - val_accuracy: 0.5789
# Epoch 8/20
# 379/379 [==============================] - 0s 922us/sample - loss: 0.3159 - accuracy: 0.8865 - val_loss: 0.6289 - val_accuracy: 0.5789
# Epoch 9/20
# 379/379 [==============================] - 0s 878us/sample - loss: 0.2992 - accuracy: 0.8786 - val_loss: 0.6203 - val_accuracy: 0.6316
# Epoch 10/20
# 379/379 [==============================] - 0s 876us/sample - loss: 0.2846 - accuracy: 0.8918 - val_loss: 0.6284 - val_accuracy: 0.6000
# Epoch 11/20
# 379/379 [==============================] - 0s 1ms/sample - loss: 0.2629 - accuracy: 0.8918 - val_loss: 0.6336 - val_accuracy: 0.5789
# Epoch 12/20
# 379/379 [==============================] - 0s 947us/sample - loss: 0.2039 - accuracy: 0.9182 - val_loss: 0.6250 - val_accuracy: 0.5895
# Epoch 13/20
# 379/379 [==============================] - 0s 847us/sample - loss: 0.2568 - accuracy: 0.9077 - val_loss: 0.6237 - val_accuracy: 0.6000
# Epoch 14/20
# 379/379 [==============================] - 0s 876us/sample - loss: 0.2106 - accuracy: 0.9261 - val_loss: 0.6264 - val_accuracy: 0.6211
# Epoch 15/20
# 379/379 [==============================] - 0s 753us/sample - loss: 0.1967 - accuracy: 0.9314 - val_loss: 0.6086 - val_accuracy: 0.6105
# Epoch 16/20
# 379/379 [==============================] - 0s 694us/sample - loss: 0.1960 - accuracy: 0.9314 - val_loss: 0.6086 - val_accuracy: 0.6526
# Epoch 17/20
# 379/379 [==============================] - 0s 670us/sample - loss: 0.1667 - accuracy: 0.9446 - val_loss: 0.5931 - val_accuracy: 0.6737
# Epoch 18/20
# 379/379 [==============================] - 0s 710us/sample - loss: 0.1736 - accuracy: 0.9446 - val_loss: 0.5791 - val_accuracy: 0.6632
# Epoch 19/20
# 379/379 [==============================] - 0s 854us/sample - loss: 0.1390 - accuracy: 0.9604 - val_loss: 0.5506 - val_accuracy: 0.7158
# Epoch 20/20
# 379/379 [==============================] - 0s 720us/sample - loss: 0.1631 - accuracy: 0.9314 - val_loss: 0.5323 - val_accuracy: 0.7158
