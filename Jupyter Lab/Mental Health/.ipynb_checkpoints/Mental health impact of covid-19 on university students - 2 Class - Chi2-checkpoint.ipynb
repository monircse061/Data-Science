# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from catboost import CatBoostClassifier
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
import warnings
warnings.filterwarnings('ignore')
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
import shap
df = pd.read_csv('C:/Users/m/Desktop/Thesis Tasks/Jupyter Lab/Mental Health/Mental health 2Class.csv')

# %%
df.sample(6)
# Out:
#      Gender Worry_about_social_support_during_covid19 Residence  \
# 58     Male                                       Yes     Urban
# 132    Male                                        No     Rural
# 153    Male                                       Yes     Rural
# 75   Female                                       Yes     Rural
# 250    Male                                        No     Urban
# 42     Male                                       Yes     Rural
#
#     Stable_family_income Living_with_parents  \
# 58                   Yes                 Yes
# 132                   No                 Yes
# 153                  Yes                 Yes
# 75                   Yes                 Yes
# 250                  Yes                 Yes
# 42                    No                 Yes
#
#     Relative_or_acquaintance_infected_with_covid19 Worry_about_academic_delay  \
# 58                                             Yes                        Yes
# 132                                             No                        Yes
# 153                                             No                        Yes
# 75                                             Yes                        Yes
# 250                                             No                        Yes
# 42                                             Yes                        Yes
#
#     Disruption_of_daily_life Exercise_during_covid19 Own_income  \
# 58                       Yes                      No         No
# 132                      Yes                      No        Yes
# 153                      Yes                     Yes         No
# 75                       Yes                     Yes         No
# 250                      Yes                      No         No
# 42                       Yes                      No         No
#
#     Quarrel_between_parents  Sleep_status_hour_during_covid19  \
# 58                      Yes                                 3
# 132                      No                                 1
# 153                      No                                 3
# 75                       No                                 2
# 250                      No                                 2
# 42                       No                                 2
#
#      Internet_browsing_hours_during_covid19  \
# 58                                        3
# 132                                       2
# 153                                       4
# 75                                        4
# 250                                       3
# 42                                        3
#
#     Fear_of_getting_infected_with_covid19 Mental_Health_Status
# 58                                    Yes                 Poor
# 132                                   Yes               Better
# 153                                    No               Better
# 75                                    Yes               Better
# 250                                   Yes               Better
# 42                                    Yes               Better

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 15 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gender                                          253 non-null    object
#  1   Worry_about_social_support_during_covid19       253 non-null    object
#  2   Residence                                       253 non-null    object
#  3   Stable_family_income                            253 non-null    object
#  4   Living_with_parents                             253 non-null    object
#  5   Relative_or_acquaintance_infected_with_covid19  253 non-null    object
#  6   Worry_about_academic_delay                      253 non-null    object
#  7   Disruption_of_daily_life                        253 non-null    object
#  8   Exercise_during_covid19                         253 non-null    object
#  9   Own_income                                      253 non-null    object
#  10  Quarrel_between_parents                         253 non-null    object
#  11  Sleep_status_hour_during_covid19                253 non-null    int64
#  12  Internet_browsing_hours_during_covid19          253 non-null    int64
#  13  Fear_of_getting_infected_with_covid19           253 non-null    object
#  14  Mental_Health_Status                            253 non-null    object
# dtypes: int64(2), object(13)
# memory usage: 29.8+ KB

# %% [markdown]
# # Output column unique value

# %%
df.Mental_Health_Status.value_counts()
# Out:
# Better    166
# Poor       87
# Name: Mental_Health_Status, dtype: int64

# %%
plt.pie(df.Mental_Health_Status.value_counts(), labels = ['Better','Poor'],colors = ['#FF5733','#FFBF00'],autopct='%1.1f%%',shadow=True, explode=(0.05, 0.05))
plt.title('Mental Health Status')
plt.show()

# %% [markdown]
# # Chi2 Test

# %% [markdown]
# ![Capturede.PNG](attachment:Capturede.PNG)

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
from scipy.stats import chi2_contingency
from scipy.stats import chi2
import scipy.stats as stats
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 as sklearn_chi2

# %%
def chi2_test(i):
    name= df.columns[i]
    chi_squared_stat, p_value, dof, expected = chi2_contingency(pd.crosstab(df[name],df["Mental_Health_Status"]))
    print('Feature Name: {0} \nCh2: {1}\n P: {2}\n DOF: {3}\n Exp: {4}'.format(df.columns[i],chi_squared_stat,p_value,dof, expected))
    print('Minimum expected value: {0} , Percentage of Exp val (<5): {1}'.format(expected.min(),len(expected[expected<5])/len(expected)*100 ))
    if p_value <= 0.05:
            print("Dependent (Association): Reject null Hypothesis")
    else:
            print('Inependent (No Association): Fail to Reject null Hypothesis')
    # Critical Value        
    critical = stats.chi2.ppf(q = 0.95, df = dof) 
    print('Critical Value: ',critical)
    if abs(chi_squared_stat)>=critical:
            print('Dependent : Reject Hypothesis 0 (null Hypothesis)')
    elif abs(chi_squared_stat)<critical:
            print('Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)')

# %%
for i in range(len(df.columns)-1):
    chi2_test(i)
    print('================================================================')
# Out:
# Feature Name: Gender
# Ch2: 0.07305943256594463
#  P: 0.7869332468700008
#  DOF: 1
#  Exp: [[ 26.24505929  13.75494071]
#  [139.75494071  73.24505929]]
# Minimum expected value: 13.754940711462451 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Worry_about_social_support_during_covid19
# Ch2: 15.156170815946217
#  P: 9.897430768237713e-05
#  DOF: 1
#  Exp: [[ 42.64822134  22.35177866]
#  [123.35177866  64.64822134]]
# Minimum expected value: 22.35177865612648 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  3.841458820694124
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Residence
# Ch2: 0.17005334303941008
#  P: 0.6800644043902678
#  DOF: 1
#  Exp: [[103.01185771  53.98814229]
#  [ 62.98814229  33.01185771]]
# Minimum expected value: 33.01185770750988 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Stable_family_income
# Ch2: 6.659374163988311
#  P: 0.009863555013809665
#  DOF: 1
#  Exp: [[97.10671937 50.89328063]
#  [68.89328063 36.10671937]]
# Minimum expected value: 36.10671936758893 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  3.841458820694124
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Living_with_parents
# Ch2: 0.516401892530687
#  P: 0.47238058103159064
#  DOF: 1
#  Exp: [[ 45.92885375  24.07114625]
#  [120.07114625  62.92885375]]
# Minimum expected value: 24.07114624505929 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Relative_or_acquaintance_infected_with_covid19
# Ch2: 0.4435780157267005
#  P: 0.5054005360190017
#  DOF: 1
#  Exp: [[83.98418972 44.01581028]
#  [82.01581028 42.98418972]]
# Minimum expected value: 42.984189723320156 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Worry_about_academic_delay
# Ch2: 2.632076710985035
#  P: 0.10472465686775093
#  DOF: 1
#  Exp: [[ 17.71541502   9.28458498]
#  [148.28458498  77.71541502]]
# Minimum expected value: 9.284584980237154 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Disruption_of_daily_life
# Ch2: 11.886381867266262
#  P: 0.0005654585745375898
#  DOF: 1
#  Exp: [[ 26.90118577  14.09881423]
#  [139.09881423  72.90118577]]
# Minimum expected value: 14.098814229249012 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  3.841458820694124
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Exercise_during_covid19
# Ch2: 1.3019469366877519
#  P: 0.2538578992708537
#  DOF: 1
#  Exp: [[101.69960474  53.30039526]
#  [ 64.30039526  33.69960474]]
# Minimum expected value: 33.69960474308301 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  3.841458820694124
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Own_income
# Ch2: 4.275960008986727
#  P: 0.03865512228557804
#  DOF: 1
#  Exp: [[136.4743083  71.5256917]
#  [ 29.5256917  15.4743083]]
# Minimum expected value: 15.474308300395258 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  3.841458820694124
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Quarrel_between_parents
# Ch2: 21.516618366015955
#  P: 2.1267952770506938e-05
#  DOF: 2
#  Exp: [[ 13.77865613   7.22134387]
#  [118.1027668   61.8972332 ]
#  [ 34.11857708  17.88142292]]
# Minimum expected value: 7.221343873517786 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  5.991464547107979
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Sleep_status_hour_during_covid19
# Ch2: 10.4929022358848
#  P: 0.0052661743073037165
#  DOF: 2
#  Exp: [[19.68379447 10.31620553]
#  [91.85770751 48.14229249]
#  [54.45849802 28.54150198]]
# Minimum expected value: 10.316205533596838 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  5.991464547107979
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Internet_browsing_hours_during_covid19
# Ch2: 0.9402703347909985
#  P: 0.8157003585158463
#  DOF: 3
#  Exp: [[15.74703557  8.25296443]
#  [33.46245059 17.53754941]
#  [41.99209486 22.00790514]
#  [74.79841897 39.20158103]]
# Minimum expected value: 8.25296442687747 , Percentage of Exp val (<5): 0.0
# Inependent (No Association): Fail to Reject null Hypothesis
# Critical Value:  7.814727903251179
# Inependent : Fail to Reject Hypothesis 0 (null Hypothesis)
# ================================================================
# Feature Name: Fear_of_getting_infected_with_covid19
# Ch2: 5.41935108458491
#  P: 0.01991476015367202
#  DOF: 1
#  Exp: [[ 61.01976285  31.98023715]
#  [104.98023715  55.01976285]]
# Minimum expected value: 31.9802371541502 , Percentage of Exp val (<5): 0.0
# Dependent (Association): Reject null Hypothesis
# Critical Value:  3.841458820694124
# Dependent : Reject Hypothesis 0 (null Hypothesis)
# ================================================================

# %%
import math, time, random, datetime

# data analysis and wrangling
import pandas_profiling
from pandas_profiling import ProfileReport

# %%
ProfileReport(df)
# Out:
# HBox(children=(HTML(value='Summarize dataset'), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# F:\New_Anaconda_Inst_Loc\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in _repr_html_(self)
#     416     def _repr_html_(self) -> None:
#     417         """The ipython notebook widgets user interface gets called by the jupyter notebook."""
# --> 418         self.to_notebook_iframe()
#     419
#     420     def __repr__(self) -> str:
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in to_notebook_iframe(self)
#     396         with warnings.catch_warnings():
#     397             warnings.simplefilter("ignore")
# --> 398             display(get_notebook_iframe(self.config, self))
#     399
#     400     def to_widgets(self) -> None:
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py in get_notebook_iframe(config, profile)
#      73         output = get_notebook_iframe_src(config, profile)
#      74     elif attribute == IframeAttribute.srcdoc:
# ---> 75         output = get_notebook_iframe_srcdoc(config, profile)
#      76     else:
#      77         raise ValueError(
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\report\presentation\flavours\widget\notebook.py in get_notebook_iframe_srcdoc(config, profile)
#      27     width = config.notebook.iframe.width
#      28     height = config.notebook.iframe.height
# ---> 29     src = html.escape(profile.to_html())
#      30
#      31     iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in to_html(self)
#     366
#     367         """
# --> 368         return self.html
#     369
#     370     def to_json(self) -> str:
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in html(self)
#     183     def html(self) -> str:
#     184         if self._html is None:
# --> 185             self._html = self._render_html()
#     186         return self._html
#     187
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in _render_html(self)
#     285         from pandas_profiling.report.presentation.flavours import HTMLReport
#     286
# --> 287         report = self.report
#     288
#     289         with tqdm(
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in report(self)
#     177     def report(self) -> Root:
#     178         if self._report is None:
# --> 179             self._report = get_report_structure(self.config, self.description_set)
#     180         return self._report
#     181
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\profile_report.py in description_set(self)
#     159     def description_set(self) -> Dict[str, Any]:
#     160         if self._description_set is None:
# --> 161             self._description_set = describe_df(
#     162                 self.config,
#     163                 self.df,
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\model\describe.py in describe(config, df, summarizer, typeset, sample)
#     125         missing_map = get_missing_active(config, table_stats)
#     126         pbar.total += len(missing_map)
# --> 127         missing = {
#     128             name: progress(get_missing_diagram, pbar, f"Missing diagram {name}")(
#     129                 config, df, settings
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\model\describe.py in <dictcomp>(.0)
#     126         pbar.total += len(missing_map)
#     127         missing = {
# --> 128             name: progress(get_missing_diagram, pbar, f"Missing diagram {name}")(
#     129                 config, df, settings
#     130             )
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\utils\progress_bar.py in inner(*args, **kwargs)
#       9     def inner(*args, **kwargs) -> Any:
#      10         bar.set_postfix_str(message)
# ---> 11         ret = fn(*args, **kwargs)
#      12         bar.update()
#      13         return ret
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\model\missing.py in get_missing_diagram(config, df, settings)
#     121         return None
#     122
# --> 123     result = handle_missing(settings["name"], settings["function"])(config, df)
#     124     if result is None:
#     125         return None
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\model\missing.py in inner(*args, **kwargs)
#      97
#      98         try:
# ---> 99             return fn(*args, *kwargs)
#     100         except ValueError as e:
#     101             warn_missing(name, str(e))
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\multimethod\__init__.py in __call__(self, *args, **kwargs)
#     182     def __call__(self, *args, **kwargs):
#     183         """Resolve and dispatch to best method."""
# --> 184         return self[tuple(map(self.get_type, args))](*args, **kwargs)
#     185
#     186     def evaluate(self):
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\model\pandas\missing_pandas.py in pandas_missing_bar(config, df)
#      18 @missing_bar.register
#      19 def pandas_missing_bar(config: Settings, df: pd.DataFrame) -> str:
# ---> 20     return plot_missing_bar(config, df)
#      21
#      22
#
# F:\New_Anaconda_Inst_Loc\lib\contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas_profiling\visualisation\missing.py in plot_missing_bar(config, data)
#      68         The resulting missing values bar plot encoded as a string.
#      69     """
# ---> 70     missingno.bar(
#      71         data,
#      72         figsize=(10, 5),
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\missingno\missingno.py in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort, ax)
#     232         figsize = None  # for behavioral consistency with other plot types, re-use the given size
#     233
# --> 234     (nullity_counts / len(df)).plot.bar(
#     235         figsize=figsize, fontsize=fontsize, log=log, color=color, ax=ax1
#     236     )
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_core.py in bar(self, x, y, **kwargs)
#    1105         other axis represents a measured value.
#    1106         """
# -> 1107         return self(kind="bar", x=x, y=y, **kwargs)
#    1108
#    1109     @Appender(
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     272         self._add_table()
#     273         self._make_legend()
# --> 274         self._adorn_subplots()
#     275
#     276         for ax in self.axes:
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_matplotlib\core.py in _adorn_subplots(self)
#     465         if len(self.axes) > 0:
#     466             all_axes = self._get_subplots()
# --> 467             nrows, ncols = self._get_axes_layout()
#     468             _handle_shared_axes(
#     469                 axarr=all_axes,
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\pandas\plotting\_matplotlib\core.py in _get_axes_layout(self)
#     881         for ax in axes:
#     882             # check axes coordinates to estimate layout
# --> 883             points = ax.get_position().get_points()
#     884             x_set.add(points[0][0])
#     885             y_set.add(points[0][1])
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\matplotlib\axes\_base.py in get_position(self, original)
#     881             locator = self.get_axes_locator()
#     882             if not locator:
# --> 883                 self.apply_aspect()
#     884             return self._position.frozen()
#     885
#
# F:\New_Anaconda_Inst_Loc\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1659         # Not sure whether we need this check:
#    1660         if shared_x and shared_y:
# -> 1661             raise RuntimeError("adjustable='datalim' is not allowed when both "
#    1662                                "axes are shared")
#    1663
#
# RuntimeError: adjustable='datalim' is not allowed when both axes are shared
